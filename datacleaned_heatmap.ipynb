# %% [markdown]
# <a href="https://colab.research.google.com/github/Qnpy2024/Data-Cleaning/blob/main/datacleaned_heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/cleaned_data.csv')
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
x = "college??"
x = x.replace("?","")
print (x)
# Out:
# college

# %%
df ["movie_title"] = df["movie_title"].str.replace("?","")
df ["movie_title"] = df["movie_title"].str.replace("ÿ","")
df ["title_year.1"] = df["title_year"].copy()
df ["DIRECTOR_facebook_likes"] = df["DIRECTOR_facebook_likes"].str.replace("\"","")
df
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 0
# dtype: int64

# %%
duration_mean = df['duration'].mean()
df['duration'].fillna(duration_mean, inplace=True)


df['DIRECTOR_facebook_likes'] = pd.to_numeric(df['DIRECTOR_facebook_likes'], errors='coerce').fillna(0).astype(int)
fblike_mean = df['DIRECTOR_facebook_likes'].mean()
df['DIRECTOR_facebook_likes'].fillna(fblike_mean, inplace=True)


numvote_mean = df['num_voted_users'].mean()
df['num_voted_users'].fillna(numvote_mean, inplace=True)


casttotal_mean = df['Cast_Total_facebook_likes'].mean()
df['Cast_Total_facebook_likes'].fillna(casttotal_mean, inplace=True)


facenumber_mean = df['facenumber_in_poster'].mean()
df['facenumber_in_poster'].fillna(facenumber_mean, inplace=True)


actor_mean = df['ACTOR_2_facebook_likes'].mean()
df['ACTOR_2_facebook_likes'].fillna(actor_mean, inplace=True)

df
# Out:
# <ipython-input-10-86b9da048bf8>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['duration'].fillna(duration_mean, inplace=True)
# <ipython-input-10-86b9da048bf8>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      0
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# Cast_Total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       0
# imdb_score                   0
# title_year.1                 0
# dtype: int64

# %%
plt.figure(figsize=(12, 10))
plt.title('Correlation Heatmap')
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
X = df.iloc[:,-3]
X.head(5)
# Out:
# 0      936.0
# 1     5000.0
# 2      393.0
# 3    23000.0
# 4      632.0
# Name: ACTOR_2_facebook_likes, dtype: float64

# %%
Y = df.iloc[:,4]
Y.head(5)
# Out:
# 0      855
# 1     1000
# 2      161
# 3    23000
# 4      530
# Name: actor_3_facebook_likes, dtype: int64

# %%
plt.scatter(X,Y)
plt.title('ACTOR_2_facebook_likes vs actor_3_facebook_likes')
plt.xlabel('ACTOR_2_facebook_likes')
plt.ylabel('actor_3_facebook_likes')
# Out:
# Text(0, 0.5, 'actor_3_facebook_likes')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=51)
linear = LinearRegression()
linear.fit(np.array(X_train).reshape(-1,1),y_train)
linear.coef_
linear.intercept_
Y_pred = linear.predict(np.array(X_test).reshape(-1,1))
Y_pred
y_test
score = r2_score(y_test,Y_pred)
score
# Out:
# 0.2219619593649289

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,Y_pred,color='red')
plt.title('ACTOR_2_facebook_likes vs actor_3_facebook_likes')
plt.xlabel('ACTOR_2_facebook_likes')
plt.ylabel('actor_3_facebook_likes')
# Out:
# Text(0, 0.5, 'actor_3_facebook_likes')

# %%
X = df.iloc[:,-3]

Y = df.iloc[:,-8]

plt.scatter(X,Y)
plt.title('ACTOR_2_facebook_likes vs Cast_Total_facebook_likes')
plt.xlabel('ACTOR_2_facebook_likes')
plt.ylabel('Cast_Total_facebook_likes')
# Out:
# Text(0, 0.5, 'Cast_Total_facebook_likes')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=51)
linear = LinearRegression()
linear.fit(np.array(X_train).reshape(-1,1),y_train)
linear.coef_
linear.intercept_
Y_pred = linear.predict(np.array(X_test).reshape(-1,1))
Y_pred
y_test
score = r2_score(y_test,Y_pred)
score

plt.scatter(X_test,y_test)
plt.plot(X_test,Y_pred,color='red')
plt.title('ACTOR_2_facebook_likes vs Cast_Total_facebook_likes')
plt.xlabel('ACTOR_2_facebook_likes')
plt.ylabel('aCast_Total_facebook_likes')
# Out:
# Text(0, 0.5, 'aCast_Total_facebook_likes')

# %%
X = df.iloc[:,4]

Y = df.iloc[:,-8]

plt.scatter(X,Y)
plt.title('actor_3_facebook_likes vs Cast_Total_facebook_likes')
plt.xlabel('actor_3_facebook_likes')
plt.ylabel('Cast_Total_facebook_likes')
# Out:
# Text(0, 0.5, 'Cast_Total_facebook_likes')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=51)
linear = LinearRegression()
linear.fit(np.array(X_train).reshape(-1,1),y_train)
linear.coef_
linear.intercept_
Y_pred = linear.predict(np.array(X_test).reshape(-1,1))
Y_pred
y_test
score = r2_score(y_test,Y_pred)
score

plt.scatter(X_test,y_test)
plt.plot(X_test,Y_pred,color='red')
plt.title('actor_3_facebook_likes vs Cast_Total_facebook_likes')
plt.xlabel('actor_3_facebook_likes')
plt.ylabel('Cast_Total_facebook_likes')
# Out:
# Text(0, 0.5, 'Cast_Total_facebook_likes')
